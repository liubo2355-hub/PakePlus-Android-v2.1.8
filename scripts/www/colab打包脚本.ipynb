# %% [markdown]
# # 学生点名系统 - APK打包脚本
#
# ## 使用步骤：
# 1. 先上传文件：main.py, buildozer.spec, students.json
# 2. 按顺序运行下面的代码块

# %%
# 第一步：安装 Buildozer 和依赖
# !pip install buildozer
# !apt-get update
# !apt-get install -y git automake libtool pkg-config
# !apt-get install -y libncurses5-dev libncursesw5-dev
# !apt-get install -y libffi-dev autoconf zlib1g-dev
# !apt-get install -y libtinfo5 cmake
# !apt-get install -y openjdk-17-jdk
# !apt-get install -y unzip
print("✅ 依赖安装完成！")

# %%
# 第二步：检查文件是否已上传
import os
files = ['main.py', 'buildozer.spec', 'students.json']
for f in files:
    if os.path.exists(f):
        print(f"✅ {f} 已找到")
    else:
        print(f"❌ {f} 未找到！请先上传！")

# %%
# 第三步：开始打包（这一步需要30-60分钟，请耐心等待）
import os
print("🚀 开始打包APK...")
print("⏰ 首次打包需要下载Android SDK/NDK，需要较长时间，请耐心等待...")
# !buildozer android debug
print("\n✅ 打包完成！")

# %%
# 第四步：检查APK文件
import os
if os.path.exists('bin'):
    print("📁 bin文件夹内容：")
    # !ls -lh bin/
    print("\n🎉 恭喜！APK文件在bin文件夹中！")
else:
    print("❌ bin文件夹不存在，请检查打包是否成功")

# %% [markdown]
# ## 下载APK文件：
#
# 打包完成后，在左侧文件浏览器中找到 `bin/` 文件夹，
# 右键点击APK文件，选择下载即可！
